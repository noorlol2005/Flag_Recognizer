# %% [markdown]
# The Data on Flags of South Asia

# %%
flags = [
    {
        "name": "Pakistan",
        "emoji": "🇵🇰",
        "colors": ["green", "white"],
        "shape": "rectangular",
        "symbol": ["crescent moon and star","crescent","crescent and star","star","5-pointed star", "5 pointed star"],
    },
    {
        "name": "India",
        "emoji": "🇮🇳",
        "colors": ["saffron","orange", "white", "green","blue"],
        "shape": "rectangular",
        "symbol": ["Ashoka Chakra","wheel","Ashoka's wheel"],
    },
    {
        "name": "Nepal",
        "emoji": "🇳🇵",
        "colors": ["red", "blue","white"],
        "shape": "triangular",
        "symbol": ["sun and moon", "crescent","crescent moon", "sun", "2 suns"],
    },
    {
        "name": "Maldives",
        "emoji": "🇲🇻",
        "colors": ["red", "green", "white"],
        "shape": "rectangular",
        "symbol": ["crescent moon", "crescent"]
    },
    {
        "name": "Bhutan",
        "emoji": "🇧🇹",
        "colors": ["yellow", "orange","white"],
        "shape": "rectangular",
        "symbol": ["dragon"]
    },
    {
        "name": "Sri Lanka",
        "emoji": "🇱🇰",
        "colors": ["yellow", "green", "orange", "maroon"],
        "shape": "rectangular",
        "symbol": ["lion with a sword", "four bo leaves", "4 bo leaves", "sword", "lion"]
    },
    {
        "name": "Bangladesh",
        "emoji": "🇧🇩",
        "colors": ["green", "red"],
        "shape": "rectangular",
        "symbol": ["red circle", "red disc"]
    }
]

def main_menu():
    while True:
        print("\nWelcome to the South Asian Flag Identifier!")
        print("1. Search by flag emoji")
        print("2. Search by flag characteristics")
        print("3. Exit")
        choice = input("Please choose an option (1, 2, or 3): ").strip()

        if choice == '1':
            search_by_emoji()
        elif choice == '2':
            search_by_characteristics()
        elif choice == '3':
            print("Thank you for using the Flag Identifier. Goodbye!")
            break
        else:
            print("Invalid option. Please choose 1, 2, or 3.")

def search_by_emoji():
    emoji_input = input("Enter the flag emoji: ").strip()
    found = False
    for flag in flags:
        if flag["emoji"] == emoji_input:
            print(f"The flag you entered is for: {flag['name']}")
            found = True
            break
    if not found:
        print("No country found with that emoji.")

def search_by_characteristics():
    print("\nSearch by Characteristics:")
    color_input = input("Enter a color (or skip by pressing Enter): ").strip().lower()

    shape_choice = input("Enter shape (1 for rectangular, 2 for square, 3 for triangular, or skip): ").strip()
    shape = ""
    if shape_choice == '1':
        shape = "rectangular"
    elif shape_choice == '2':
        shape = "square"
    elif shape_choice == '3':
        shape = "triangular"

    symbol_input = ""
    symbol_query_option = input("Do you want to search by symbol? (yes/no, or skip by pressing Enter): ").strip().lower()

    if symbol_query_option == 'yes':
        symbol_input = input("What is the symbol? (e.g., crescent moon, dragon): ").strip().lower()
    elif symbol_query_option != 'no' and symbol_query_option != '':
        print("Invalid input for symbol search option. Skipping symbol search.")

    results = []
    for flag in flags:
        match = True

        if color_input:
            found_color = False
            # Ensure all colors in the flag's list are lowercased for accurate comparison
            # This allows for partial matches if 'orange' is in 'light orange'
            for c in flag["colors"]:
                if color_input in c: # c is already lowercase from the data structure, so no c.lower() needed here
                    found_color = True
                    break
            if not found_color:
                match = False

        if shape and flag["shape"] != shape:
            match = False

        if symbol_input:
            found_symbol = False
            for s in flag["symbol"]:
                # s is already lowercase from the data structure
                if symbol_input in s:
                    found_symbol = True
                    break
            if not found_symbol:
                match = False

        if match:
            results.append(flag)

    if results:
        print("\nHere are the flags that match your criteria:")
        for flag in results:
            print(f"- {flag['name']} {flag['emoji']}")
    else:
        print("No flags found matching your criteria.")

# Call the main menu to start the program
main_menu()
# Out:
# Welcome to the South Asian Flag Identifier!
# 1. Search by flag emoji
# 2. Search by flag characteristics
# 3. Exit
#
# Search by Characteristics:
#
# Here are the flags that match your criteria:
# - Pakistan 🇵🇰
# - Nepal 🇳🇵
# - Maldives 🇲🇻
#
# Welcome to the South Asian Flag Identifier!
# 1. Search by flag emoji
# 2. Search by flag characteristics
# 3. Exit

# %% [markdown]
# x-x-x

# %%
flags = [
    {
        "name": "Pakistan",
        "emoji": "🇵🇰",
        "colors": ["green", "white"],
        "shape": "rectangular",
        "symbol": ["crescent moon and star","crescent","crescent and star","star","5-pointed star", "5 pointed star"],
    },
    {
        "name": "India",
        "emoji": "🇮🇳",
        "colors": ["saffron","orange", "white", "green","blue"],
        "shape": "rectangular",
        "symbol": ["Ashoka Chakra","wheel","Ashoka's wheel"],
    },
    {
        "name": "Nepal",
        "emoji": "🇳🇵",
        "colors": ["red", "blue","white"],
        "shape": "triangular",
        "symbol": ["sun and moon", "crescent","crescent moon", "sun", "2 suns"],
    },
    {
        "name": "Maldives",
        "emoji": "🇲🇻",
        "colors": ["red", "green", "white"],
        "shape": "rectangular",
        "symbol": "crescent moon"
    },
    {
        "name": "Bhutan",
        "emoji": "🇧🇹",
        "colors": ["yellow", "orange","white"],
        "shape": "rectangular",
        "symbol": ["dragon"]
    },
    {
        "name": "Sri Lanka",
        "emoji": "🇱🇰",
        "colors": ["yellow", "green", "orange", "maroon"],
        "shape": "rectangular",
        "symbol": ["lion with a sword", "four bo leaves", "4 bo leaves", "sword", "lion"]
    },
    {
        "name": "Bangladesh",
        "emoji": "🇧🇩",
        "colors": ["green", "red"],
        "shape": "rectangular",
        "symbol": ["red circle", "red disc"]
    }
]


def main_menu():
    while True:
        print("\nWelcome to the South Asian Flag Identifier!")
        print("1. Search by flag emoji")
        print("2. Search by flag characteristics")
        print("3. Exit")
        choice = input("Please choose an option (1, 2, or 3): ").strip()

        if choice == '1':
            search_by_emoji()
        elif choice == '2':
            search_by_characteristics()
        elif choice == '3':
            print("Thank you for using the Flag Identifier. Goodbye!")
            break
        else:
            print("Invalid option. Please choose 1, 2, or 3.")

def search_by_emoji():
    emoji_input = input("Enter the flag emoji: ").strip()
    found = False
    for flag in flags:
        if flag["emoji"] == emoji_input:
            print(f"The flag you entered is for: {flag['name']}")
            found = True
            break
    if not found:
        print("No country found with that emoji.")

def search_by_characteristics():
    print("\nSearch by Characteristics:")

    # Start with all flags as potential results
    current_results = list(flags) # Create a mutable copy

    # --- 1. Filter by Color ---
    color_input = input("Enter a color (or skip by pressing Enter): ").strip().lower()
    if color_input:
        filtered_by_color = []
        for flag in current_results:
            found_color = False
            for c in flag["colors"]:
                if color_input in c:
                    found_color = True
                    break
            if found_color:
                filtered_by_color.append(flag)
        current_results = filtered_by_color
        if not current_results: # If no flags match color, stop here
            print("No flags found matching your criteria.")
            return

    # --- 2. Filter by Shape ---
    shape_choice = input("Enter shape (1 for rectangular, 2 for square, 3 for triangular, or skip): ").strip()
    shape = ""
    if shape_choice == '1':
        shape = "rectangular"
    elif shape_choice == '2':
        shape = "square"
    elif shape_choice == '3':
        shape = "triangular"

    if shape: # Only filter if a shape was provided
        filtered_by_shape = []
        for flag in current_results:
            if flag["shape"] == shape:
                filtered_by_shape.append(flag)
        current_results = filtered_by_shape
        if not current_results: # If no flags match shape (after color), stop here
            print("No flags found matching your criteria.")
            return

    # --- 3. Filter by Symbol ---
    symbol_input = ""
    # Ask explicitly if they want to search by symbol, expecting 'yes' or 'no'
    search_by_symbol_option = input("Do you want to search by symbol? (yes/no, or skip by pressing Enter for 'no'): ").strip().lower()

    if search_by_symbol_option == 'yes':
        symbol_input = input("What is the symbol? (e.g., crescent moon, dragon): ").strip().lower()
        if not symbol_input: # If they said 'yes' but entered nothing for the symbol
            print("No symbol entered. Skipping symbol search.")
            # current_results remain as they were after shape filter
    elif search_by_symbol_option == 'no' or search_by_symbol_option == '':
        # User explicitly said 'no' or skipped, so no symbol filtering happens
        pass
    else:
        print("Invalid input for symbol search option. Skipping symbol search.")
        # current_results remain as they were after shape filter


    if symbol_input: # Only filter by symbol if a specific symbol was provided
        filtered_by_symbol = []
        for flag in current_results:
            found_symbol = False
            for s in flag["symbol"]:
                if symbol_input in s:
                    found_symbol = True
                    break
            if found_symbol:
                filtered_by_symbol.append(flag)
        current_results = filtered_by_symbol

    # --- Final Output ---
    if current_results:
        print("\nHere are the flags that match your criteria:")
        for flag in current_results:
            print(f"- {flag['name']} {flag['emoji']}")
    else:
        print("No flags found matching your criteria.")

# Call the main menu to start the program
main_menu()
# Out:
# Welcome to the South Asian Flag Identifier!
# 1. Search by flag emoji
# 2. Search by flag characteristics
# 3. Exit
# Please choose an option (1, 2, or 3): 1
# Enter the flag emoji: 🇧🇩
# The flag you entered is for: Bangladesh
#
# Welcome to the South Asian Flag Identifier!
# 1. Search by flag emoji
# 2. Search by flag characteristics
# 3. Exit
# Please choose an option (1, 2, or 3): 2
#
# Search by Characteristics:
# Enter a color (or skip by pressing Enter): green
# Enter shape (1 for rectangular, 2 for square, 3 for triangular, or skip): 1
# Do you want to search by symbol? (yes/no, or skip by pressing Enter for 'no'): yes
# What is the symbol? (e.g., crescent moon, dragon): crescent
#
# Here are the flags that match your criteria:
# - Pakistan 🇵🇰
#
# Welcome to the South Asian Flag Identifier!
# 1. Search by flag emoji
# 2. Search by flag characteristics
# 3. Exit
